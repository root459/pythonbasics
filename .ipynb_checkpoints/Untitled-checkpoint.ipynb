# %%
class Items:
    def __init__(self):
        self.bakery_items = {
    1: {"item": "Croissant", "price": 185.00},  
    2: {"item": "Baguette", "price": 220.00},   
    3: {"item": "Cinnamon Roll", "price": 150.00},  
    4: {"item": "Sourdough Bread", "price": 340.00},  
    5: {"item": "Chocolate Chip Cookie", "price": 110.00}  
        }
    def add_item(self):
        while True:
            try:
                food_item=input("enter new item and if done then enter 0")
                if food_item=="0":
                    break
                price=int(input("enter item price"))
                if not (int(price)>=0 and price.isdigit()):
                    raise Exception
                else:
                    self.item=max(self.bakery_items.keys())+1
                    self.bakery_items=self.bakery_items[item]={"item":food_item,"price":price}
                    print("Item added succesfully")
            except Exception as e:
                print("Enter valid price")
                pass
a=Items()
a.add_item()

# %%
import datetime


class Orders:
    order_no=0
    def __init__(self,name):
        self.order_id=order_No()
        self.items=item
        self.name=name
        self.date_time=date.datetime()
    @staticmethod
    def order_No():
        return order_no+1

# %%
class Items:
    def __init__(self):
        self.item=0
        self.bakery_items = {
    1: {"item": "Croissant", "price": 185.00},  
    2: {"item": "Baguette", "price": 220.00},   
    3: {"item": "Cinnamon Roll", "price": 150.00},  
    4: {"item": "Sourdough Bread", "price": 340.00},  
    5: {"item": "Chocolate Chip Cookie", "price": 110.00}  
        }
    def add_item(self):
        while True:
            try:
                food_item=input("enter new item and if done then enter 0")
                if food_item=="0":
                    break
                price=int(input("enter item price"))
                if not price>=0:
                    raise Exception
                else:
                    self.item=max(self.bakery_items.keys())+1
                    self.bakery_items=self.bakery_items[self.item]={"item":food_item,"price":price}
                    print("Item added succesfully")
            except Exception as e:
                print("Enter valid price and Item not added")
                pass
    def remove_item
a=Items()
a.add_item()
